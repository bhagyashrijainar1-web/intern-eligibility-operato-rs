# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagyashrijainar1-web/intern-eligibility-operato-rs/blob/main/Module_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Product Return Eligibility Checker

# Input
days = int(input("Enter days since delivery: "))
condition = input("Enter product condition (Good/Damaged): ")

# Check return eligibility
if days <= 7 and condition == "Good":
    print("Return Accepted")
else:
    print("Return Rejected")
# Out:
# Enter days since delivery: 6
# Enter product condition (Good/Damaged): Good
# Return Accepted
