# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagyashrijainar1-web/intern-eligibility-operato-rs/blob/main/Module_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Inventory Stock Level Monitor

# Input values
opening_stock = int(input("Enter Opening Stock: "))
items_sold = int(input("Enter Items Sold: "))

# Calculate remaining stock (Arithmetic Operator)
remaining_stock = opening_stock - items_sold

print("Remaining Stock:", remaining_stock)

# Check reorder level (Relational Operator)
if remaining_stock < 20:
    print("Reorder Required")
else:
    print("Stock Sufficient")
# Out:
# Enter Opening Stock: 50
# Enter Items Sold: 35
# Remaining Stock: 15
# Reorder Required
