# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagyashrijainar1-web/intern-eligibility-operato-rs/blob/main/Module_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data Usage Alert System

# Input
total_data = float(input("Enter total data limit (GB): "))
data_used = float(input("Enter data used (GB): "))

# Calculate usage percentage
usage_percentage = (data_used / total_data) * 100

# Check usage status
if usage_percentage >= 90:
    print("High Usage Alert")
elif usage_percentage >= 70 and usage_percentage < 90:
    print("Warning")
else:
    print("Normal Usage")
# Out:
# Enter total data limit (GB): 10
# Enter data used (GB): 8
# Warning
